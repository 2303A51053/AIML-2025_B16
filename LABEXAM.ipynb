# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51053/AIML-2025_B16/blob/main/LABEXAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %%
X, y = make_classification(n_samples=500, n_features=2, n_informative=2, n_redundant=0, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
svm_linear = SVC(kernel='linear')
svm_linear.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_linear = svm_linear.predict(X_test)
accuracy_linear = accuracy_score(y_test, y_pred_linear)
print(f"Accuracy (Linear Kernel): {accuracy_linear}")
# Out:
# Accuracy (Linear Kernel): 0.88

# %%
cm_linear = confusion_matrix(y_test, y_pred_linear)
print("Confusion Matrix (Linear Kernel):")
print(cm_linear)
ConfusionMatrixDisplay(confusion_matrix=cm_linear).plot()
plt.show()
# Out:
# Confusion Matrix (Linear Kernel):
# [[64 14]
#  [ 4 68]]

# %%
def plot_decision_boundary(X, y, model, ax, title):
    h = .02  # step size in the mesh
    x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = model.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.contourf(xx, yy, Z, alpha=0.8)
    ax.scatter(X[:, 0], X[:, 1], c=y, edgecolors='k', marker='o')
    ax.set_title(title)
fig, ax = plt.subplots()
plot_decision_boundary(X, y, svm_linear, ax, "Decision Boundary for SVM (Linear Kernel)")
plt.show()

# %%
svm_rbf = SVC(kernel='rbf')
svm_rbf.fit(X_train, y_train)
y_pred_rbf = svm_rbf.predict(X_test)
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)
print(f"Accuracy (RBF Kernel): {accuracy_rbf}")
# Out:
# Accuracy (RBF Kernel): 0.8733333333333333

# %%
cm_rbf = confusion_matrix(y_test, y_pred_rbf)
print("Confusion Matrix (RBF Kernel):")
print(cm_rbf)
ConfusionMatrixDisplay(confusion_matrix=cm_rbf).plot()
plt.show()
# Out:
# Confusion Matrix (RBF Kernel):
# [[63 15]
#  [ 4 68]]

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
svm_linear_scaled = SVC(kernel='linear')
svm_linear_scaled.fit(X_train_scaled, y_train)
y_pred_linear_scaled = svm_linear_scaled.predict(X_test_scaled)
accuracy_linear_scaled = accuracy_score(y_test, y_pred_linear_scaled)
print(f"Accuracy (Linear Kernel with Scaling): {accuracy_linear_scaled}")
# Out:
# Accuracy (Linear Kernel with Scaling): 0.88

# %%
cm_linear_scaled = confusion_matrix(y_test, y_pred_linear_scaled)
print("Confusion Matrix (Linear Kernel with Scaling):")
print(cm_linear_scaled)
ConfusionMatrixDisplay(confusion_matrix=cm_linear_scaled).plot()
plt.show()
# Out:
# Confusion Matrix (Linear Kernel with Scaling):
# [[64 14]
#  [ 4 68]]
